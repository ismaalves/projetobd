# %% [markdown]
# # Projeto Banco de Dados - Sistema de Venda de Ingressos

# %% [markdown]
# ## Ideias de implementação do modelo relacional

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
